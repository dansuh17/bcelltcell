# %%
import h5py
import os
import numpy as np
from scipy import misc
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['image.cmap'] = 'gray'

# %%
data_folder = './HL60'
filelist = os.listdir()
with h5py.File(os.path.join(data_folder, 'image-final_0000.h5'), 'r') as hf:
    for att in hf:
        print(att)
        
    print(hf['Image'])
    print(np.array(hf['Image'][35]))
    plt.imshow(hf['Image'][45])
# Out:
# AdditionalImageInformation
# DimensionScaleX
# DimensionScaleY
# DimensionScaleZ
# Image
# XOffset
# YOffset
# ZOffset
# <HDF5 dataset "Image": shape (129, 565, 807), type "<u2">
# [[96 97 83 ..., 89 98 92]
#  [94 89 85 ..., 98 92 95]
#  [87 94 96 ..., 84 89 84]
#  ...,
#  [84 90 91 ..., 87 94 94]
#  [84 95 90 ..., 86 95 94]
#  [86 89 89 ..., 90 91 90]]
